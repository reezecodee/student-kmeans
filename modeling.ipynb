# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('exam_test.csv')
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
data.drop(['EthnicGroup', 'ParentEduc', 'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings', 'TransportMeans', 'WklyStudyHours'], axis=1, inplace=True)
data
# Out:
#        Unnamed: 0  Gender     LunchType  MathScore  ReadingScore  WritingScore
# 0               0  female      standard         71            71            74
# 1               1  female      standard         69            90            88
# 2               2  female      standard         87            93            91
# 3               3    male  free/reduced         45            56            42
# 4               4    male      standard         76            78            75
# ...           ...     ...           ...        ...           ...           ...
# 30636         816  female      standard         59            61            65
# 30637         890    male      standard         58            53            51
# 30638         911  female  free/reduced         61            70            67
# 30639         934  female      standard         82            90            93
# 30640         960    male      standard         64            60            58
#
# ...

# %%
data
# Out:
#        Unnamed: 0  Gender     LunchType  MathScore  ReadingScore  WritingScore
# 0               0  female      standard         71            71            74
# 1               1  female      standard         69            90            88
# 2               2  female      standard         87            93            91
# 3               3    male  free/reduced         45            56            42
# 4               4    male      standard         76            78            75
# ...           ...     ...           ...        ...           ...           ...
# 30636         816  female      standard         59            61            65
# 30637         890    male      standard         58            53            51
# 30638         911  female  free/reduced         61            70            67
# 30639         934  female      standard         82            90            93
# 30640         960    male      standard         64            60            58
#
# ...

# %%
data['LunchType'].value_counts()
# Out:
# LunchType
# standard        19905
# free/reduced    10736
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Gender          0
# LunchType       0
# MathScore       0
# ReadingScore    0
# WritingScore    0
# dtype: int64

# %%
data[data["LunchType"] == "standard"].head(10)
# Out:
#     Unnamed: 0  Gender LunchType  MathScore  ReadingScore  WritingScore
# 0            0  female  standard         71            71            74
# 1            1  female  standard         69            90            88
# 2            2  female  standard         87            93            91
# 4            4    male  standard         76            78            75
# 5            5  female  standard         73            84            79
# 6            6  female  standard         85            93            89
# 10          10    male  standard         58            54            52
# 11          11    male  standard         40            52            43
# 12          12  female  standard         66            82            74
# 13          13    male  standard         80            73            71

# %%
data[data["LunchType"] == "free/reduced"].head(10)
# Out:
#     Unnamed: 0  Gender     LunchType  MathScore  ReadingScore  WritingScore
# 3            3    male  free/reduced         45            56            42
# 7            7    male  free/reduced         41            43            39
# 8            8    male  free/reduced         65            64            68
# 9            9  female  free/reduced         37            59            50
# 17          17  female  free/reduced         18            32            28
# 18          18    male  free/reduced         46            42            47
# 19          19  female  free/reduced         50            56            58
# 21          21  female  free/reduced         65            75            70
# 24          24    male  free/reduced         74            71            80
# 25          25    male  free/reduced         75            76            76

# %%
data.describe()
# Out:
#          Unnamed: 0     MathScore  ReadingScore  WritingScore
# count  30641.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607     66.558402     69.377533     68.418622
# std      288.747894     15.361616     14.758952     15.443525
# min        0.000000      0.000000     10.000000      4.000000
# 25%      249.000000     56.000000     59.000000     58.000000
# 50%      500.000000     67.000000     70.000000     69.000000
# 75%      750.000000     78.000000     80.000000     79.000000
# max      999.000000    100.000000    100.000000    100.000000

# %%
data.sample(5)
# Out:
#        Unnamed: 0  Gender     LunchType  MathScore  ReadingScore  WritingScore
# 13645         478    male  free/reduced         64            60            56
# 7482          915  female  free/reduced         59            57            59
# 9925          497    male  free/reduced         64            56            56
# 8399          891  female      standard         66            63            70
# 6100          435  female      standard         58            65            69

# %%
np.mean(data["MathScore"])
# Out:
# 66.5584021409223

# %%
data
# Out:
#        Unnamed: 0  Gender     LunchType  MathScore  ReadingScore  WritingScore
# 0               0  female      standard         71            71            74
# 1               1  female      standard         69            90            88
# 2               2  female      standard         87            93            91
# 3               3    male  free/reduced         45            56            42
# 4               4    male      standard         76            78            75
# ...           ...     ...           ...        ...           ...           ...
# 30636         816  female      standard         59            61            65
# 30637         890    male      standard         58            53            51
# 30638         911  female  free/reduced         61            70            67
# 30639         934  female      standard         82            90            93
# 30640         960    male      standard         64            60            58
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['LunchType'] = le.fit_transform(data['LunchType'])
data
# Out:
#        Unnamed: 0  Gender  LunchType  MathScore  ReadingScore  WritingScore
# 0               0  female          1         71            71            74
# 1               1  female          1         69            90            88
# 2               2  female          1         87            93            91
# 3               3    male          0         45            56            42
# 4               4    male          1         76            78            75
# ...           ...     ...        ...        ...           ...           ...
# 30636         816  female          1         59            61            65
# 30637         890    male          1         58            53            51
# 30638         911  female          0         61            70            67
# 30639         934  female          1         82            90            93
# 30640         960    male          1         64            60            58
#
# [30641 rows x 6 columns]

# %%
data["LunchType"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='LunchType'>

# %%
plt.scatter(data=data, x="MathScore", y="ReadingScore")

# %%
# lakukan penghapusan data yang hilang
data.dropna()

# %%
# pemilihan fitur dan target

features = ['Gender', 'WklyStudyHours', 'MathScore', 'ReadingScore', 'WritingScore']
X = data[features]
y = data['Performance']
